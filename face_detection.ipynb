# %% [markdown]
# <a href="https://colab.research.google.com/github/kitarp07/Face-Detection/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import time
import cv2
import uuid
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# try:
#   tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
#   print(tpu.cluster_spec().as_dict()['worker'])

# except ValueError:
#   raise BaseException("error")
# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)
# strategy = tf.distribute.TPUStrategy(tpu)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.0

# %%
import rarfile
# Replace 'aug_images.zip' with the actual name of your zip file
with rarfile.RarFile('/content/drive/MyDrive/aug_images.rar', 'r') as rar_ref:
    rar_ref.extractall()

# %%
# image_path = os.path.join('data', 'images')
# number_of_images = 30

# %%
# cap = cv2.VideoCapture(0)
# for imgnum in range(number_of_images):
#     print('Collecting image {}'.format(imgnum))
#     ret, frame = cap.read()
#     img_name =os.path.join(image_path, f'{str(uuid.uuid1())}.jpg')
#     cv2.imwrite(img_name, frame)
#     cv2.imshow('frame', frame)
#     time.sleep(0.5)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()
# Out:
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19
# Collecting image 20
# Collecting image 21
# Collecting image 22
# Collecting image 23
# Collecting image 24
# Collecting image 25
# Collecting image 26
# Collecting image 27
# Collecting image 28
# Collecting image 29

# %%
# import labelme

# %%
# !labelme

# %%
# import json

# %%
# #load images

# images = tf.data.Dataset.list_files("data\\images\\*.jpg", shuffle=False)

# %%
# images.as_numpy_iterator().next()
# Out:
# b'data\\images\\1081ae60-1883-11ee-a732-d812654bd3c7.jpg'

# %%
# def load_img(path):
#     img_file = tf.io.read_file(path)
#     img = tf.io.decode_jpeg(img_file)
#     return img

# %%
# images = images.map(load_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 images = images.map(load_img)
#
# NameError: name 'images' is not defined

# %%
# images.as_numpy_iterator().next()
# Out:
# array([[[ 24,   3,  10],
#         [ 24,   3,   8],
#         [ 28,   3,   9],
#         ...,
#         [ 72,  91, 123],
#         [ 72,  89, 119],
#         [ 73,  90, 120]],
#
#        [[ 22,   1,   8],
#         [ 23,   2,   7],
#         [ 26,   4,   7],
#         ...,
#         [ 69,  88, 118],
#         [ 79,  98, 128],
#         [ 74,  93, 123]],
#
#        [[ 23,   2,   7],
#         [ 24,   4,   6],
#         [ 28,   6,   9],
#         ...,
#         [ 79, 100, 127],
#         [ 76,  97, 124],
#         [ 75,  96, 123]],
#
#        ...,
#
#        [[ 64,  39,   8],
#         [ 66,  41,  10],
#         [ 67,  42,  11],
#         ...,
#         [209, 214, 208],
#         [208, 213, 207],
#         [210, 215, 209]],
#
#        [[ 67,  40,  11],
#         [ 69,  42,  13],
#         [ 69,  42,  13],
#         ...,
#         [212, 215, 208],
#         [209, 212, 205],
#         [211, 214, 207]],
#
#        [[ 67,  37,   9],
#         [ 69,  39,  11],
#         [ 69,  39,  11],
#         ...,
#         [212, 215, 208],
#         [210, 213, 206],
#         [213, 216, 209]]], dtype=uint8)

# %%
# type(images)
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %%
img_gen = images.batch(4).as_numpy_iterator()

# %%
# pics = img_gen.next()
# fig, ax = plt.subplots( ncols=4 , figsize=(10,10))
# for i, j in enumerate(pics):
#     ax[i].imshow(j)
# plt.show()

# %%
# for file in os.listdir(os.path.join('data', 'train', 'images')):
#     img_filename = file.split('.')[0]
#     filename = file.split('.')[0] + '.json'
#     filepath = os.path.join('data','train', 'label', filename)
#     if os.path.exists(filepath):
#         new_path = os.path.join('data', 'train', 'label', filename)
#         print(f'{new_path} exists')

#     else:
#         p = img_filename + '.jpg'
#         p2 = os.path.join('data','train','images', p)
#         os.remove(p2)
# Out:
# data\train\label\1081ae60-1883-11ee-a732-d812654bd3c7.json exists
# data\train\label\1124ea98-1883-11ee-be0c-d812654bd3c7.json exists
# data\train\label\11753f58-1883-11ee-b8fd-d812654bd3c7.json exists
# data\train\label\12147e86-1883-11ee-bd47-d812654bd3c7.json exists
# data\train\label\12652368-1883-11ee-a3b6-d812654bd3c7.json exists
# data\train\label\1306a870-1883-11ee-a609-d812654bd3c7.json exists
# data\train\label\13559e1c-1883-11ee-a396-d812654bd3c7.json exists
# data\train\label\1443dbaf-1883-11ee-951b-d812654bd3c7.json exists
# data\train\label\14928aa9-1883-11ee-b925-d812654bd3c7.json exists
# data\train\label\15347439-1883-11ee-aea4-d812654bd3c7.json exists
# data\train\label\158322a6-1883-11ee-9157-d812654bd3c7.json exists
# data\train\label\1625101b-1883-11ee-9f74-d812654bd3c7.json exists
# data\train\label\1677800c-1883-11ee-9a89-d812654bd3c7.json exists
# data\train\label\16c864ee-1883-11ee-8726-d812654bd3c7.json exists
# data\train\label\1719aaff-1883-11ee-bbac-d812654bd3c7.json exists
# data\train\label\17bb11f0-1883-11ee-8962-d812654bd3c7.json exists
# data\train\label\185e5662-1883-11ee-9208-d812654bd3c7.json exists
# data\train\label\18b1a8ab-1883-11ee-a3d5-d812654bd3c7.json exists
# data\train\label\19024777-1883-11ee-8de1-d812654bd3c7.json exists
# data\train\label\1952d022-1883-11ee-845e-d812654bd3c7.json exists
# data\train\label\19a301ab-1883-11ee-88a1-d812654bd3c7.json exists
# data\train\label\3018dc61-1883-11ee-8d23-d812654bd3c7.json exists
# data\train\label\30676e65-1883-11ee-a954-d812654bd3c7.json exists
# data\train\label\3108aae9-1883-11ee-bb6f-d812654bd3c7.json exists
# data\train\label\31599de5-1883-11ee-9ea8-d812654bd3c7.json exists
# data\train\label\324ca168-1883-11ee-b4ba-d812654bd3c7.json exists
# data\train\label\329d7470-1883-11ee-a415-d812654bd3c7.json exists
# data\train\label\333f5744-1883-11ee-8c6e-d812654bd3c7.json exists
# data\train\label\33904c20-1883-11ee-be6e-d812654bd3c7.json exists
# data\train\label\34335319-1883-11ee-9e83-d812654bd3c7.json exists
# data\train\label\e6dff394-1882-11ee-a55b-d812654bd3c7.json exists
# data\train\label\e730465c-1882-11ee-a8ba-d812654bd3c7.json exists
# data\train\label\e78180cd-1882-11ee-b663-d812654bd3c7.json exists
# data\train\label\e7d25216-1882-11ee-a8af-d812654bd3c7.json exists
# data\train\label\e82309c6-1882-11ee-9a49-d812654bd3c7.json exists
# data\train\label\e873051c-1882-11ee-991e-d812654bd3c7.json exists
# data\train\label\e8c22345-1882-11ee-ad06-d812654bd3c7.json exists
# data\train\label\e91265f9-1882-11ee-ab37-d812654bd3c7.json exists
# data\train\label\e9634188-1882-11ee-b82a-d812654bd3c7.json exists
# data\train\label\e9b3f227-1882-11ee-9af5-d812654bd3c7.json exists
# data\train\label\ea046e64-1882-11ee-9600-d812654bd3c7.json exists
# data\train\label\ea55b836-1882-11ee-a1cf-d812654bd3c7.json exists
# data\train\label\eaa64257-1882-11ee-b03d-d812654bd3c7.json exists
# data\train\label\eaf7343b-1882-11ee-bd3f-d812654bd3c7.json exists
# data\train\label\eb483095-1882-11ee-8202-d812654bd3c7.json exists
# data\train\label\eb98d726-1882-11ee-b517-d812654bd3c7.json exists
# data\train\label\ebea1fac-1882-11ee-b326-d812654bd3c7.json exists
# data\train\label\ec3ab0fa-1882-11ee-914d-d812654bd3c7.json exists
# data\train\label\ec8b6d95-1882-11ee-85fb-d812654bd3c7.json exists
# data\train\label\ecdbb9a4-1882-11ee-8cc1-d812654bd3c7.json exists
# data\train\label\ed2c3955-1882-11ee-b16c-d812654bd3c7.json exists
# data\train\label\ed7d13b6-1882-11ee-9851-d812654bd3c7.json exists
# data\train\label\edcd8f00-1882-11ee-915a-d812654bd3c7.json exists
# data\train\label\ee1e31f4-1882-11ee-8400-d812654bd3c7.json exists
# data\train\label\ee6ee0d8-1882-11ee-b79e-d812654bd3c7.json exists
# data\train\label\eebff3b8-1882-11ee-839f-d812654bd3c7.json exists
# data\train\label\ef1124d8-1882-11ee-ab56-d812654bd3c7.json exists
# data\train\label\ef61645f-1882-11ee-a5d9-d812654bd3c7.json exists
# data\train\label\efb1e0d1-1882-11ee-ad72-d812654bd3c7.json exists

# %%
# Image augmentation

import albumentations as alb

# %%
augmentor = alb.Compose(
    [alb.RandomCrop(width=450, height=450),
    alb.HorizontalFlip(p=0.5),
    alb.RandomBrightnessContrast(p=0.2),
    alb.RandomGamma(p=0.2),
    alb.RGBShift(p=0.2),
    alb.VerticalFlip(p=0.5)],
    bbox_params=alb.BboxParams(format='albumentations',
                              label_fields=['class_labels'])

)

# %%
imgg = cv2.imread(os.path.join('data','train','images','1081ae60-1883-11ee-a732-d812654bd3c7.jpg'))

# %%
imgg.shape
# Out:
# (480, 640, 3)

# %%
with open(os.path.join('data', 'train', 'label' , '1081ae60-1883-11ee-a732-d812654bd3c7.json'), 'r') as f:
    label =json.load(f)

# %%
label['shapes'][0]['points']
# Out:
# [[285.16853932584274, 241.12359550561797],
#  [478.42696629213486, 443.37078651685397]]

# %%
coords =[0,0,0,0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
coords = list(np.divide(coords,[640, 480,640, 480]))

# %%
coords
# Out:
# [0.4455758426966293,
#  0.5023408239700374,
#  0.7475421348314607,
#  0.9236891385767791]

# %%
aug_img = augmentor(image=imgg, bboxes=[coords], class_labels=['face'])

# %%
aug_img['image'].shape
# Out:
# (450, 450, 3)

# %%
aug_img['bboxes']
# Out:
# [(0.12349563046192258,
#   0.5247191011235955,
#   0.5529588014981273,
#   0.9741573033707865)]

# %%
cv2.rectangle(
aug_img['image'],
tuple(np.multiply(aug_img['bboxes'][0][:2],[450, 450]).astype(int)),
tuple(np.multiply(aug_img['bboxes'][0][2:],[450, 450]).astype(int)),
(255, 0, 0), 2)

plt.imshow(aug_img['image'])

# %%
for folder in ['train', 'test', 'val']:
    for img in os.listdir(os.path.join('data',folder, 'images')):
        imgFile = cv2.imread(os.path.join('data',folder,'images', img))

        coords = [0,0,0.00001, 0.000001]

        label_path = os.path.join('data', folder, 'label', f'{img.split(".")[0]}.json')

        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)
            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]

            coords = list(np.divide(coords,[640, 480,640, 480]))
        try:
            for x in range(60):
                augmented_imgs = augmentor(image=imgFile, bboxes = [coords], class_labels=['face'])

                cv2.imwrite(os.path.join('aug_images', folder, 'images', f'{img.split(".")[0]}.{x}.jpg'), augmented_imgs['image'])

                annotation = {}

                annotation['image'] = img

                if os.path.exists(label_path):
                    if len(augmented_imgs['bboxes']) == 0:
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0
                    else:
                        annotation['bbox'] = augmented_imgs['bboxes'][0]
                        annotation['class'] = 1
                else:
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0

                with open(os.path.join('aug_images', folder, 'label', f'{img.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)
        except Exception as e:
            print(e)

# %%
def load_img(path):
    img_file = tf.io.read_file(path)
    img = tf.io.decode_jpeg(img_file)
    return img

# %%
print(os.getcwd())
# Out:
# /content

# %%
train_images = tf.data.Dataset.list_files('/content/aug_images/train/images/*.jpg', shuffle=False)

# %%
train_images=train_images.map(load_img)

# %%
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))

# %%
train_images = train_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('/content/aug_images/val/images/*.jpg', shuffle=False)
val_images=val_images.map(load_img)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('/content/aug_images/test/images/*.jpg', shuffle=False)
test_images=test_images.map(load_img)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
train_images.as_numpy_iterator().next()
# Out:
# array([[[0.95349264, 0.9530637 , 0.91286767],
#         [0.7384804 , 0.688174  , 0.60398287],
#         [0.7766544 , 0.6856618 , 0.49693626],
#         ...,
#         [0.3485294 , 0.24558823, 0.22107843],
#         [0.33609068, 0.22383578, 0.20324755],
#         [0.33382353, 0.22303921, 0.19313726]],
#
#        [[0.95980394, 0.9602941 , 0.92990196],
#         [0.70134807, 0.6555147 , 0.5905637 ],
#         [0.7432598 , 0.65067405, 0.5070466 ],
#         ...,
#         [0.35202205, 0.259375  , 0.25104168],
#         [0.33137256, 0.2372549 , 0.22169118],
#         [0.33903188, 0.24705882, 0.22708334]],
#
#        [[0.8693015 , 0.88645834, 0.8685049 ],
#         [0.69393384, 0.67536765, 0.63756126],
#         [0.7485907 , 0.66384804, 0.5745711 ],
#         ...,
#         [0.36764705, 0.2735294 , 0.25784314],
#         [0.36764705, 0.27009803, 0.25441176],
#         [0.36844364, 0.2704044 , 0.25079656]],
#
#        ...,
#
#        [[0.5897059 , 0.597549  , 0.67990196],
#         [0.56715685, 0.575     , 0.6573529 ],
#         [0.5480392 , 0.55588233, 0.6382353 ],
#         ...,
#         [0.33333334, 0.21973039, 0.18829657],
#         [0.33278185, 0.22794117, 0.19944853],
#         [0.24816176, 0.1538603 , 0.13621323]],
#
#        [[0.5648897 , 0.5761642 , 0.6516544 ],
#         [0.5450368 , 0.55631125, 0.6318015 ],
#         [0.5328431 , 0.5441176 , 0.61960787],
#         ...,
#         [0.33431372, 0.22843137, 0.2009804 ],
#         [0.31427696, 0.22310048, 0.19908088],
#         [0.23186274, 0.15735294, 0.13872549]],
#
#        [[0.57395834, 0.5808211 , 0.6528799 ],
#         [0.55784315, 0.5668505 , 0.62990195],
#         [0.5384191 , 0.5452819 , 0.6173407 ],
#         ...,
#         [0.33333334, 0.23143382, 0.21556373],
#         [0.31519607, 0.22107843, 0.21715686],
#         [0.23088235, 0.15006128, 0.15196079]]], dtype=float32)

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding='utf-8') as f:
              label = json.load(f)
    return [label['class']], label['bbox']

# %%
train_labels = tf.data.Dataset.list_files('/content/aug_images/train/label/*.json', shuffle=False)
train_labels.as_numpy_iterator().next()
# Out:
# b'/content/aug_images/train/label/1081ae60-1883-11ee-a732-d812654bd3c7.0.json'

# %%
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
train_labels
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.uint8, name=None), TensorSpec(shape=<unknown>, dtype=tf.float16, name=None))>

# %%
test_labels = tf.data.Dataset.list_files('/content/aug_images/test/label/*.json', shuffle=False)
test_labels.as_numpy_iterator().next()
# Out:
# b'/content/aug_images/test/label/10d4b068-1883-11ee-97d0-d812654bd3c7.0.json'

# %%
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))
test_labels
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.uint8, name=None), TensorSpec(shape=<unknown>, dtype=tf.float16, name=None))>

# %%
val_labels = tf.data.Dataset.list_files('/content/aug_images/val/label/*.json', shuffle=False)
val_labels.as_numpy_iterator().next()
# Out:
# b'/content/aug_images/val/label/12b694ef-1883-11ee-aa13-d812654bd3c7.0.json'

# %%
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))
val_labels
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.uint8, name=None), TensorSpec(shape=<unknown>, dtype=tf.float16, name=None))>

# %%
train_labels.as_numpy_iterator().next()
# Out:
# (array([1], dtype=uint8),
#  array([0.2856, 0.0725, 0.7153, 0.522 ], dtype=float16))

# %%
len(train_images), len(train_labels)
# Out:
# (3540, 3540)

# %%
len(test_images), len(test_labels)
# Out:
# (900, 900)

# %%
len(val_images), len(val_labels)
# Out:
# (900, 900)

# %%
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(5000)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(5000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[0].shape
# Out:
# (8, 120, 120, 3)

# %%
samples = val.as_numpy_iterator()

# %%
ds = samples.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))

for idx in range(4):
    ds_img = ds[0][idx]
    ds_coords = ds[1][1][idx]

    cv2.rectangle(ds_img,
                  tuple(np.multiply(ds_coords[:2], [120,120]).astype(int)),
                  tuple(np.multiply(ds_coords[2:], [120,120]).astype(int)),

                  (255, 0, 0), 2)
    ax[idx].imshow(ds_img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
vgg16 = tf.keras.applications.VGG16(include_top = False)

# %%
vgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def detect_face_model():
  inputt = tf.keras.layers.Input(shape=(120,120,3))

  vgg = tf.keras.applications.VGG16(include_top=False)(inputt)

  f1 = tf.keras.layers.GlobalMaxPooling2D()(vgg)
  class1 = tf.keras.layers.Dense(2048, activation='relu')(f1)
  class2 = tf.keras.layers.Dense(1, activation='sigmoid')(class1)

  f2 = tf.keras.layers.GlobalMaxPooling2D()(vgg)
  regress1 = tf.keras.layers.Dense(2048, activation='relu')(f2)
  regress2 = tf.keras.layers.Dense(4, activation= 'sigmoid')(regress1)

  detect_face = tf.keras.models.Model(inputs=inputt, outputs=[class2, regress2])

  return detect_face

# %%
detect_face = detect_face_model()

# %%
detect_face.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 120, 120, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, None, None,   14714688    ['input_12[0][0]']
#                                 512)
#
#  global_max_pooling2d_8 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  global_max_pooling2d_9 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  dense_16 (Dense)               (None, 2048)         1050624     ['global_max_pooling2d_8[0][0]']
#
#  dense_18 (Dense)               (None, 2048)         1050624     ['global_max_pooling2d_9[0][0]']
#
#  dense_17 (Dense)               (None, 1)            2049        ['dense_16[0][0]']
#
#  dense_19 (Dense)               (None, 4)            8196        ['dense_18[0][0]']
#
# ==================================================================================================
# Total params: 16,826,181
# Trainable params: 16,826,181
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x, y = train.as_numpy_iterator().next()

# %%
x.shape, y
# Out:
# ((8, 120, 120, 3),
#  (array([[1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1]], dtype=uint8),
#   array([[0.164  , 0.05   , 0.541  , 0.502  ],
#          [0.     , 0.614  , 0.2615 , 0.953  ],
#          [0.409  , 0.4348 , 0.8286 , 0.954  ],
#          [0.914  , 0.6313 , 1.     , 0.971  ],
#          [0.2437 , 0.05997, 0.6855 , 0.4495 ],
#          [0.     , 0.525  , 0.3137 , 0.927  ],
#          [0.5767 , 0.04922, 1.     , 0.6235 ],
#          [0.5317 , 0.5474 , 0.9062 , 1.     ]], dtype=float16)))

# %%
len(train)
# Out:
# 443

# %%
batches_per_epoch = len(train)

# %%
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_decay)

# %%
opt = tf.keras.optimizers.Adam(learning_rate = 0.0001)

# %%
def localization_loss(y_true, y_pred):
    delta_coord = tf.reduce_sum(tf.square(y_true[:, :2] - y_pred[:, :2]))

    h_true = y_true[:, 3] - y_true[:, 1]
    w_true = y_true[:,2] - y_true[:, 0]

    h_pred = y_pred[:, 3] - y_pred[:, 1]
    w_pred = y_pred[:,2] - y_pred[:, 0]

    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true - h_pred))

    return delta_coord + delta_size

# %%
class_loss = tf.keras.losses.BinaryCrossentropy()
regression_loss = localization_loss

# %%
class DetectFace(tf.keras.models.Model):
    def __init__(self, detect_face, **kwargs):
        super().__init__(**kwargs)
        self.model = detect_face
    def compile(self, opt, class_loss, regression_loss, **kwargs):
        super().compile(**kwargs)
        self.class_loss = class_loss
        self.coord_loss = regression_loss
        self.opt = opt

    def train_step(self, batch, **kwargs):
        x,y = batch

        with tf.GradientTape() as tape:
            classes, coords = self.model(x, training = True)
            batch_class_loss = self.class_loss(y[0], classes)
            batch_coord_loss = self.coord_loss(tf.cast(y[1], tf.float32), coords)

            total_loss = batch_class_loss * 0.5 + batch_coord_loss

            grad = tape.gradient(total_loss, self.model.trainable_variables)

        opt.apply_gradients(zip(grad, self.model.trainable_variables))

        return{"total_loss":total_loss, "classification_loss": batch_class_loss, "regression_loss": batch_coord_loss}

    def test_step(self, batch, **kwargs):
        x,y = batch


        classes, coords = self.model(x, training = False)
        batch_class_loss = self.class_loss(y[0], classes)
        batch_coord_loss = self.coord_loss(tf.cast(y[1], tf.float32), coords)

        total_loss = batch_class_loss * 0.5 + batch_coord_loss

        return{"total_loss":total_loss, "classification_loss": batch_class_loss, "regression_loss": batch_coord_loss}
    def call(self, x, **kwargs):
        return self.model(x, **kwargs)

# %%
detect_face_1 = detect_face_model()

# %%
model = DetectFace(detect_face_1)

# %%
model.compile(opt, class_loss, regression_loss)

# %%
history = model.fit(train, epochs=10, validation_data = val)
# Out:
# Epoch 1/10
# 443/443 [==============================] - 49s 71ms/step - total_loss: 0.3395 - classification_loss: 0.0636 - regression_loss: 0.3077 - val_total_loss: 0.0511 - val_classification_loss: 0.0290 - val_regression_loss: 0.0366
# Epoch 2/10
# 443/443 [==============================] - 37s 69ms/step - total_loss: 0.1367 - classification_loss: 0.0249 - regression_loss: 0.1242 - val_total_loss: 0.0127 - val_classification_loss: 1.6161e-04 - val_regression_loss: 0.0126
# Epoch 3/10
# 443/443 [==============================] - 41s 71ms/step - total_loss: 0.0894 - classification_loss: 0.0167 - regression_loss: 0.0811 - val_total_loss: 0.0733 - val_classification_loss: 0.0208 - val_regression_loss: 0.0629
# Epoch 4/10
# 443/443 [==============================] - 36s 68ms/step - total_loss: 0.0840 - classification_loss: 0.0139 - regression_loss: 0.0771 - val_total_loss: 0.0409 - val_classification_loss: 1.4106e-04 - val_regression_loss: 0.0408
# Epoch 5/10
# 443/443 [==============================] - 37s 67ms/step - total_loss: 0.0862 - classification_loss: 0.0157 - regression_loss: 0.0784 - val_total_loss: 0.0361 - val_classification_loss: 0.0066 - val_regression_loss: 0.0328
# Epoch 6/10
# 443/443 [==============================] - 38s 68ms/step - total_loss: 0.0638 - classification_loss: 0.0081 - regression_loss: 0.0598 - val_total_loss: 0.0222 - val_classification_loss: 3.2993e-05 - val_regression_loss: 0.0222
# Epoch 7/10
# 443/443 [==============================] - 40s 71ms/step - total_loss: 0.0444 - classification_loss: 0.0052 - regression_loss: 0.0418 - val_total_loss: 0.0725 - val_classification_loss: 0.0278 - val_regression_loss: 0.0585
# Epoch 8/10
# 443/443 [==============================] - 38s 71ms/step - total_loss: 0.0407 - classification_loss: 0.0041 - regression_loss: 0.0387 - val_total_loss: 0.0182 - val_classification_loss: 1.2688e-04 - val_regression_loss: 0.0181
# Epoch 9/10
# 443/443 [==============================] - 36s 67ms/step - total_loss: 0.0272 - classification_loss: 0.0013 - regression_loss: 0.0266 - val_total_loss: 0.0156 - val_classification_loss: 2.5541e-05 - val_regression_loss: 0.0156
# Epoch 10/10
# 443/443 [==============================] - 38s 67ms/step - total_loss: 0.0198 - classification_loss: 1.9406e-04 - regression_loss: 0.0197 - val_total_loss: 0.0270 - val_classification_loss: 3.0995e-06 - val_regression_loss: 0.0270

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(history.history['total_loss'])
ax[0].plot(history.history['val_total_loss'])

ax[1].plot(history.history['classification_loss'])
ax[1].plot(history.history['val_classification_loss'])

ax[2].plot(history.history['regression_loss'])
ax[2].plot(history.history['val_regression_loss'])

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample= test_data.next()

# %%
y_pred = detect_face_1.predict(test_sample[0])
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
y_pred
# Out:
# [array([[0.9999987 ],
#         [0.9999981 ],
#         [0.99999166],
#         [0.9999242 ],
#         [0.9997738 ],
#         [0.9999925 ],
#         [0.99998426],
#         [0.99999666]], dtype=float32),
#  array([[0.64768624, 0.01451117, 0.9893259 , 0.42317182],
#         [0.22830833, 0.02242929, 0.6776704 , 0.44141084],
#         [0.9304125 , 0.5837363 , 0.99297136, 0.9857421 ],
#         [0.403159  , 0.517318  , 0.8029295 , 0.9637449 ],
#         [0.237397  , 0.08111861, 0.65672344, 0.52689517],
#         [0.1501633 , 0.54721355, 0.52531165, 0.9792138 ],
#         [0.37614727, 0.45602912, 0.8051053 , 0.9598107 ],
#         [0.00824779, 0.4738184 , 0.25337824, 0.9686802 ]], dtype=float32)]

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))

for idx in range(4):
    dst_img = test_sample[0][idx]
    dst_coords = y_pred[1][idx]

    if y_pred[0][idx] > 0.5:
          cv2.rectangle(dst_img,
                        tuple(np.multiply(dst_coords[:2], [120,120]).astype(int)),
                        tuple(np.multiply(dst_coords[2:], [120,120]).astype(int)),

                        (255, 0, 0), 2)
    ax[idx].imshow(dst_img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
detect_face_1.save('detect_face_1.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
